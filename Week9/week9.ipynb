# %% [markdown]
# # Bank marketing (Campaign) project
#
#
# # Team member: Supin Hooda
# # Batch code: LISUM25
# # Submitted to: Data Glacier

# %% [markdown]
# # Dataset link: https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
#importing required libraries

import pandas as pd

# %%
#reading the dataset

df = pd.read_csv(r'C:\Users\hooda\Desktop\data glacier\bank-additional\bank-additional-full.csv', delimiter=';')
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.iloc[0]
# Out:
# age                        56
# job                 housemaid
# marital               married
# education            basic.4y
# default                    no
# housing                    no
# loan                       no
# contact             telephone
# month                     may
# day_of_week               mon
# duration                  261
# campaign                    1
# pdays                     999
# previous                    0
# poutcome          nonexistent
# emp.var.rate              1.1
# cons.price.idx         93.994
# cons.conf.idx           -36.4
# euribor3m               4.857
# nr.employed            5191.0
# y                          no
# Name: 0, dtype: object

# %%
df.shape
# Out:
# (41188, 21)

# %%
df.duplicated().sum()
# Out:
# 12

# %%
df.drop_duplicates(keep = 'first', inplace = True)
print(df.duplicated().sum())
print(df.shape)
# Out:
# 0
# (41176, 21)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.drop('duration', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'campaign', 'pdays', 'previous',
#        'poutcome', 'emp.var.rate', 'cons.price.idx', 'cons.conf.idx',
#        'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41176 entries, 0 to 41187
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  campaign        41176 non-null  int64
#  11  pdays           41176 non-null  int64
#  12  previous        41176 non-null  int64
#  13  poutcome        41176 non-null  object
#  14  emp.var.rate    41176 non-null  float64
#  15  cons.price.idx  41176 non-null  float64
#  16  cons.conf.idx   41176 non-null  float64
# ...

# %%
df.describe()
# Out:
#                age      campaign         pdays      previous  emp.var.rate  \
# count  41176.00000  41176.000000  41176.000000  41176.000000  41176.000000
# mean      40.02380      2.567879    962.464810      0.173013      0.081922
# std       10.42068      2.770318    186.937102      0.494964      1.570883
# min       17.00000      1.000000      0.000000      0.000000     -3.400000
# 25%       32.00000      1.000000    999.000000      0.000000     -1.800000
# 50%       38.00000      2.000000    999.000000      0.000000      1.100000
# 75%       47.00000      3.000000    999.000000      0.000000      1.400000
# max       98.00000     56.000000    999.000000      7.000000      1.400000
#
#        cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count    41176.000000   41176.000000  41176.000000  41176.000000
# mean        93.575720     -40.502863      3.621293   5167.034870
# std          0.578839       4.627860      1.734437     72.251364
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ## Outlier Detection IQR

# %%
# List of numerical columns with potential outliers
numerical_columns = ['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
                     'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# Create subplots to display box plots for each numerical column
plt.figure(figsize=(12, 8))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    plt.boxplot(df[column], vert=False)
    plt.title(f'Box Plot of {column}')
    plt.grid()

plt.tight_layout()
plt.show()

# %% [markdown]
# No missing data in the dataset

# %%
#checking statistics of outlier features

df[['age', 'pdays', 'campaign', 'previous']].describe()
# Out:
#                age         pdays      campaign      previous
# count  41176.00000  41176.000000  41176.000000  41176.000000
# mean      40.02380    962.464810      2.567879      0.173013
# std       10.42068    186.937102      2.770318      0.494964
# min       17.00000      0.000000      1.000000      0.000000
# 25%       32.00000    999.000000      1.000000      0.000000
# 50%       38.00000    999.000000      2.000000      0.000000
# 75%       47.00000    999.000000      3.000000      0.000000
# max       98.00000    999.000000     56.000000      7.000000

# %% [markdown]
# ## Imputation using Mean

# %%
# Calculate the mean, median, and mode of the "campaign" column
mean_campaign = df['campaign'].mean()
median_campaign = df['campaign'].median()
mode_campaign = df['campaign'].mode().values[0]

# Define a function to replace outliers in the "campaign" column
def replace_outliers_campaign(value):
    if value > 20:  # Define your threshold for outliers
        return mean_campaign  # Replace with mean
        # You can replace with median or mode as needed
    else:
        return value

# Apply the function to the "campaign" column
df['campaign'] = df['campaign'].apply(replace_outliers_campaign)

# Save the modified DataFrame to a new variable or overwrite the existing one
# For example, you can save it as a new DataFrame 'df_cleaned':
df_cleaned = df

# %% [markdown]
# ## Imputation using median

# %%
# Calculate the mean, median, and mode of the "campaign" column
mean_campaign = df['campaign'].mean()
median_campaign = df['campaign'].median()
mode_campaign = df['campaign'].mode().values[0]

# Define a function to replace outliers in the "campaign" column
def replace_outliers_campaign(value):
    if value > 20:  # Define your threshold for outliers
        return median_campaign  # Replace with median
        # You can replace with median or mode as needed
    else:
        return value

# Apply the function to the "campaign" column
df['campaign'] = df['campaign'].apply(replace_outliers_campaign)

# Save the modified DataFrame to a new variable or overwrite the existing one
# For example, you can save it as a new DataFrame 'df_cleaned':
df_cleaned = df

# %% [markdown]
# # Imputation using Mode

# %%
# Calculate the mean, median, and mode of the "campaign" column
mean_campaign = df['campaign'].mean()
median_campaign = df['campaign'].median()
mode_campaign = df['campaign'].mode().values[0]

# Define a function to replace outliers in the "campaign" column
def replace_outliers_campaign(value):
    if value > 20:  # Define your threshold for outliers
        return mode_campaign  # Replace with mode
        # You can replace with median or mode as needed
    else:
        return value

# Apply the function to the "campaign" column
df['campaign'] = df['campaign'].apply(replace_outliers_campaign)

# Save the modified DataFrame to a new variable or overwrite the existing one
# For example, you can save it as a new DataFrame 'df_cleaned':
df_cleaned = df

# %% [markdown]
# Statictics of the dataset after both median and mean imputation remains more or less the same

# %%
# List of numerical columns with potential outliers
numerical_columns = ['age', 'campaign', 'pdays', 'previous', 'emp.var.rate',
                     'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

# Create subplots to display box plots for each numerical column
plt.figure(figsize=(12, 8))
for i, column in enumerate(numerical_columns, 1):
    plt.subplot(3, 3, i)
    plt.boxplot(df[column], vert=False)
    plt.title(f'Box Plot of {column}')
    plt.grid()

plt.tight_layout()
plt.show()
